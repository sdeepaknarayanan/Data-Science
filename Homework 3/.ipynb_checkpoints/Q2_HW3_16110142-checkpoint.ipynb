# %% [markdown]
# ### Implementation of the Push, and the Approximate PageRank Algorithms

# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt

# %%
G = nx.Graph()
dataset = open('com-amazon.ungraph.txt','r')
for i in dataset:
    b = i.split()
    if b[0]!='#':
        G.add_edge(int(b[0]),int(b[1]))
G.remove_edges_from(nx.selfloop_edges(G))
dataset.close()

# %%
l_nodes = list(G.nodes)
new_node = {}
for i in range(len(l_nodes)):
    new_node[l_nodes[i]] = i

# %%
new_node
# Out:
# {1: 0,
#  88160: 1,
#  118052: 2,
#  161555: 3,
#  244916: 4,
#  346495: 5,
#  444232: 6,
#  447165: 7,
#  500600: 8,
#  2: 9,
#  27133: 10,
#  62291: 11,
#  170507: 12,
#  299250: 13,
#  326776: 14,
#  331042: 15,
#  411179: 16,
#  451149: 17,
#  454888: 18,
#  4: 19,
#  16050: 20,
#  286286: 21,
#  310803: 22,
#  320519: 23,
#  408108: 24,
#  448284: 25,
#  5: 26,
#  173362: 27,
#  305321: 28,
#  407216: 29,
#  489756: 30,
#  6: 31,
#  162248: 32,
#  298989: 33,
#  398542: 34,
#  495077: 35,
#  7: 36,
#  30028: 37,
#  47672: 38,
#  355935: 39,
#  8: 40,
#  10758: 41,
#  55461: 42,
#  60605: 43,
#  148586: 44,
#  184847: 45,
#  242156: 46,
#  445607: 47,
#  453513: 48,
#  10: 49,
#  80558: 50,
#  192929: 51,
#  266485: 52,
#  500235: 53,
#  504757: 54,
#  11: 55,
#  57761: 56,
#  107436: 57,
#  400957: 58,
#  512424: 59,
#  12: 60,
#  386032: 61,
#  15: 62,
#  67084: 63,
#  85444: 64,
#  252980: 65,
#  422732: 66,
#  425706: 67,
#  428290: 68,
#  16: 69,
#  128935: 70,
#  148997: 71,
#  422237: 72,
#  17: 73,
#  18919: 74,
#  309780: 75,
#  18: 76,
#  41174: 77,
#  45026: 78,
#  168895: 79,
#  19: 80,
#  203677: 81,
#  20: 82,
#  23251: 83,
#  25337: 84,
#  61306: 85,
#  186932: 86,
#  218984: 87,
#  412652: 88,
#  450610: 89,
#  476125: 90,
#  21: 91,
#  17723: 92,
#  50332: 93,
#  62691: 94,
#  96553: 95,
#  114681: 96,
#  152202: 97,
#  166829: 98,
#  184384: 99,
#  198272: 100,
#  234603: 101,
#  297444: 102,
#  320969: 103,
#  340707: 104,
#  421307: 105,
#  505568: 106,
#  528460: 107,
#  536600: 108,
#  538669: 109,
#  545557: 110,
#  547758: 111,
#  22: 112,
#  444558: 113,
#  511266: 114,
#  531052: 115,
#  25: 116,
#  329631: 117,
#  483212: 118,
#  517449: 119,
#  26: 120,
#  95368: 121,
#  295866: 122,
#  309111: 123,
#  393249: 124,
#  410291: 125,
#  439826: 126,
#  486444: 127,
#  27: 128,
#  172631: 129,
#  385665: 130,
#  483393: 131,
#  28: 132,
#  319831: 133,
#  444973: 134,
#  29: 135,
#  56517: 136,
#  103486: 137,
#  247356: 138,
#  254470: 139,
#  260536: 140,
#  321434: 141,
#  425568: 142,
#  515736: 143,
#  31: 144,
#  85159: 145,
#  199627: 146,
#  32: 147,
#  207011: 148,
#  270841: 149,
#  333027: 150,
#  474442: 857,
#  531154: 858,
#  232: 859,
#  194723: 860,
#  269287: 861,
#  311079: 862,
#  407042: 863,
#  422952: 864,
#  233: 865,
#  27532: 866,
#  247393: 867,
#  316528: 868,
#  239: 869,
#  49153: 870,
#  180729: 871,
#  243521: 872,
#  358255: 873,
#  400275: 874,
#  419022: 875,
#  514822: 876,
#  529884: 877,
#  241: 878,
#  61712: 879,
#  104703: 880,
#  339572: 881,
#  486708: 882,
#  242: 883,
#  395268: 884,
#  462059: 885,
#  501048: 886,
#  244: 887,
#  142987: 888,
#  314794: 889,
#  356172: 890,
#  363077: 891,
#  417631: 892,
#  246: 893,
#  103415: 894,
#  286091: 895,
#  315325: 896,
#  448907: 897,
#  248: 898,
#  201746: 899,
#  419053: 900,
#  436875: 901,
#  249: 902,
#  90010: 903,
#  274409: 904,
#  277359: 905,
#  313147: 906,
#  405502: 907,
#  408687: 908,
#  458090: 909,
#  483744: 910,
#  250: 911,
#  38917: 912,
#  79024: 913,
#  114249: 914,
#  184926: 915,
#  209461: 916,
#  302978: 917,
#  328775: 918,
#  344630: 919,
#  349715: 920,
#  412302: 921,
#  440262: 922,
#  458647: 923,
#  251: 924,
#  133857: 925,
#  227688: 926,
#  231534: 927,
#  232421: 928,
#  463539: 929,
#  545796: 930,
#  252: 931,
#  17838: 932,
#  19119: 933,
#  30038: 934,
#  84301: 935,
#  141482: 936,
#  153166: 937,
#  225668: 938,
#  287268: 939,
#  312147: 940,
#  352789: 941,
#  379280: 942,
#  397159: 943,
#  413713: 944,
#  413714: 945,
#  488936: 946,
#  503746: 947,
#  524691: 948,
#  533878: 949,
#  254: 950,
#  547522: 951,
#  548091: 952,
#  255: 953,
#  57654: 954,
#  97124: 955,
#  428865: 956,
#  487320: 957,
#  516543: 958,
#  256: 959,
#  27567: 960,
#  178765: 961,
#  257653: 962,
#  257: 963,
#  54999: 964,
#  70845: 965,
#  95480: 966,
#  176397: 967,
#  208459: 968,
#  239652: 969,
#  494839: 970,
#  524833: 971,
#  259: 972,
#  78803: 973,
#  411375: 974,
#  261: 975,
#  51447: 976,
#  202605: 977,
#  336421: 978,
#  438723: 979,
#  500424: 980,
#  263: 981,
#  296929: 982,
#  421538: 983,
#  264: 984,
#  162283: 985,
#  265: 986,
#  89926: 987,
#  145733: 988,
#  182045: 989,
#  202368: 990,
#  205069: 991,
#  226672: 992,
#  312767: 993,
#  331030: 994,
#  345355: 995,
#  441138: 996,
#  460219: 997,
#  489725: 998,
#  512156: 999,
#  ...}

# %%
alpha = 0.2 
epsilon = 0.01

# %%
def push(G,p, r, u):
    p_ = np.copy(p)
    r_ = np.copy(r)
    p_[new_node[u]] = p[new_node[u]] + alpha*r[new_node[u]]
    r_[new_node[u]] = (1-alpha)*r[new_node[u]]/2
    for nbr in G.neighbors(u):
        r_[new_node[nbr]] = r[new_node[nbr]] + (1-alpha)*r[new_node[u]]/(2*G.degree(u))
    return p_, r_

def condition(G,r,epsilon):
    nodes = list(G.nodes)
    flag = 0
    list_nodes = []
    for i in range(len(nodes)):
        if r[new_node[nodes[i]]]/G.degree(nodes[i])>=epsilon:
            list_nodes.append(nodes[i])
            flag = 1
    if flag==1:
        return 1,list_nodes
    else:
        return 0, []

def approximate_page_rank(G, v, alpha, epsilon):
    p = np.zeros(G.number_of_nodes())
    r = np.zeros(G.number_of_nodes())
    r[v] = 1
    is_sat, nodes = condition(G,r,epsilon)
    while(condition(G,r,epsilon)[0]):
        nodes = condition(G,r,epsilon)[1]
        u = np.random.choice(nodes)
        p,r  = push(G,p,r,u)
    return p

# %%
p = approximate_page_rank(G,100,0.2,0.01)

# %%
p
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
p.sum()
# Out:
# 0.38976000000000005

# %% [markdown]
# ### Implementation of the Conducatance plots

# %%
seed_nodes = [514553 ,
4965 ,
143608,
243284,
152623 ,
533768,
59217 ,
99373 ,
89325 ]
new_list = [new_node[i] for i in seed_nodes]

# %%
p_all = []
sup = {}
for i in range(5):
    p = approximate_page_rank(G,new_list[i],0.2,0.005)
    p_all.append(p)
    support = 0
    for j in range(len(p)):
        if p[j]!=0:
            support+=1
            if new_list[i] in sup:
                sup[new_list[i]].append([j])
            else:
                sup[new_list[i]]=[j]
    print(seed_nodes[i],"Support is",support)
# Out:
# 514553 Support is 9
# 4965 Support is 14
# 143608 Support is 13
# 243284 Support is 11
# 152623 Support is 16

# %%
for i in sup:
    new = []
    for j in sup[i]:
        if type(j)==list:
            new.append(j[0])
        else:
            new.append(j)
    sup[i] = new

# %%
sup
# Out:
# {15643: [15629, 15634, 15635, 15638, 15643, 41424, 181251, 181252, 237071],
#  19069: [19069,
#   19070,
#   19071,
#   19072,
#   19073,
#   19074,
#   19075,
#   19076,
#   19077,
#   19078,
#   19079,
#   19080,
#   19081,
#   296295],
#  22185: [22182,
#   22185,
#   48935,
#   48937,
#   48938,
#   137165,
#   214560,
#   214562,
#   214563,
#   214564,
#   258065,
#   258066,
#   258067],
#  109380: [46163,
#   109378,
#   109379,
#   109380,
#   109381,
#   122767,
#   208559,
#   208560,
#   208561,
#   208562,
#   225783],
#  142143: [142142,
#   142143,
#   264691,
#   264692,
#   264693,
#   264694,
#   264695,
#   264696,
#   264697,
#   264698,
#   264699,
#   264700,
#   264701,
#   264702,
#   264703,
#   264704]}

# %%
node_conductance = {}
for i in new_node:
    for j in sup_keys:
        if new_node[i]==j:
            node_conductance[i]=[]

# %%
node_conductance
# Out:
# {514553: [], 4965: [], 143608: [], 243284: [], 152623: []}

# %%
for i in node_conductance:
    for j in sup[new_node[i]]:
        for k in new_node:
            if new_node[k]==j:
                node_conductance[i].append(k)

# %%
p_mapping = {}
p_mapping[514553] = p_all[0]
p_mapping[4965] = p_all[1]
p_mapping[143608] = p_all[2]
p_mapping[243284] = p_all[3]

p_mapping[152623] = p_all[4]

# %%
final = []
new_dict = {i:0 for i in node_conductance}

for i in node_conductance:
    new_list_ = []
    for j in range(len(node_conductance[i])):
        new_list_.append((node_conductance[i][j],p_mapping[i][new_node[node_conductance[i][j]]]/G.degree(node_conductance[i][j])))
    final.append(new_list_)

# %%
import operator

# %%
for elem in range(len(final)):
    final[elem] = (sorted(final[elem],key=lambda x:(-x[1],x[0])))

# %%
final
# Out:
# [[(514553, 0.030301899242296693),
#   (193615, 0.004374013848679635),
#   (526511, 0.004298722367105399),
#   (11498, 0.003754660462692604),
#   (77359, 0.0035790633608815433),
#   (73615, 0.002855231070571031),
#   (236357, 0.0023675557254468913),
#   (211337, 0.001150890087282374),
#   (261066, 0.0010100633080765565)],
#  [(4965, 0.02757451037063166),
#   (475168, 0.0042351505114893466),
#   (340053, 0.0030604931547837584),
#   (350004, 0.0030472911210833297),
#   (333303, 0.002742364451939623),
#   (47863, 0.002660727369047248),
#   (540486, 0.002404275294753581),
#   (8826, 0.0019254008529071302),
#   (436167, 0.0014095238095238097),
#   (397977, 0.0013432313781017702),
#   (436171, 0.0013333333333333335),
#   (211119, 0.0010969457807758494),
#   (436170, 0.0010772685557515187),
#   (235278, 0.0010292122436873921)],
#  [(143608, 0.014971361732154357),
#   (539820, 0.00228893927941547),
#   (255775, 0.0019478983455110445),
#   (366418, 0.0014971361732154357),
#   (13732, 0.001251716805240615),
#   (5829, 0.0011977089385723485),
#   (187370, 0.0011977089385723485),
#   (327145, 0.0011977089385723485),
#   (377884, 0.0011977089385723485),
#   (410887, 0.0011977089385723485),
#   (410943, 0.0011977089385723485),
#   (419483, 0.0011977089385723485),
#   (507155, 0.0011977089385723485)],
#  [(243284, 0.036209809137773274),
#   (36240, 0.007832700619336152),
#   (108203, 0.007595523829534824),
#   (42176, 0.007479591432857629),
#   (150741, 0.007310147656079269),
#   (501901, 0.007010935573759261),
#   (181169, 0.006527909993859935),
#   (375470, 0.006327749570483931),
#   (93547, 0.005490850004027518),
#   (419212, 0.005437019248883741),
#   (344212, 0.00429672936341196)],
#  [(152623, 0.016693035392000004),
#   (371052, 0.0020693035392000004),
#   (524713, 0.0020693035392000004),
#   (51511, 0.001568408),
#   (156415, 0.001568408),
#   (251888, 0.001568408),
#   (261897, 0.001568408),
#   (503142, 0.001568408),
#   (508151, 0.001568408),
#   (510977, 0.001568408),
#   (520180, 0.001568408),
#   (501512, 0.001404),
#   (336439, 0.0012547264),
#   (436219, 0.0012547264),
#   (480016, 0.0012547264),
#   (526119, 0.0012547264)]]

# %%
new_arr_cond = []
for i in range(len(final)):
    new_arr_cond.append([])
    for j in range(len(final[i])):
        new_arr_cond[i].append(final[i][j][0])

# %%
new_arr_cond[0][:1]
# Out:
# [514553]

# %%
conductance_cuts = {i:[] for i in range(len(final))}
for i in range(len(final)):
    for j in range(len(new_arr_cond[i])):
        try:
            temp = nx.algorithms.cuts.conductance(G,new_arr_cond[i][:j])
            print(i,j,temp)
            conductance_cuts[i].append(temp)
        except:
            continue
# Out:
# 0 1 1.0
# 0 2 0.8666666666666667
# 0 3 0.7894736842105263
# 0 4 0.75
# 0 5 0.7142857142857143
# 0 6 0.6470588235294118
# 0 7 0.5348837209302325
# 0 8 0.45454545454545453
# 1 1 1.0
# 1 2 0.875
# 1 3 0.8181818181818182
# 1 4 0.7142857142857143
# 1 5 0.6470588235294118
# 1 6 0.5609756097560976
# 1 7 0.5416666666666666
# 1 8 0.4642857142857143
# 1 9 0.49206349206349204
# 1 10 0.3972602739726027
# 1 11 0.4
# 1 12 0.38271604938271603
# 1 13 0.3333333333333333
# 2 1 1.0
# 2 2 0.9166666666666666
# 2 3 0.8518518518518519
# 2 4 0.8064516129032258
# 2 5 0.6666666666666666
# 2 6 0.6585365853658537
# 2 7 0.6521739130434783
# 2 8 0.6470588235294118
# 2 9 0.6428571428571429
# 2 10 0.639344262295082
# 2 11 0.6363636363636364
# 2 12 0.6338028169014085
# 3 1 1.0
# 3 2 0.8571428571428571
# 3 3 0.7777777777777778
# 3 4 0.7272727272727273
# 3 5 0.6923076923076923
# 3 6 0.6774193548387096
# 3 7 0.5675675675675675
# 3 8 0.4883720930232558
# 3 9 0.3076923076923077
# 3 10 0.16666666666666666
# 4 1 1.0
# 4 2 0.9166666666666666
# 4 3 0.8571428571428571
# 4 4 0.8125
# 4 5 0.7777777777777778
# 4 6 0.75
# 4 7 0.7272727272727273
# 4 8 0.7083333333333334
# 4 9 0.6923076923076923
# 4 10 0.6785714285714286
# 4 11 0.6666666666666666
# 4 12 0.65625
# 4 13 0.6521739130434783
# 4 14 0.6486486486486487
# 4 15 0.6455696202531646

# %%
for i in conductance_cuts:
    plt.figure()
    len1 = len(conductance_cuts[i])
    plt.title('Conductance vs k for seed node '+str(i+1))
    plt.xlabel('k')
    plt.ylabel('Conductance')
    plt.plot(range(len1),conductance_cuts[i])

# %% [markdown]
# ### Precision plots, obtained across multiple communities

# %%
file_precision = open('com-amazon.all.dedup.cmty.txt')
presence = {i:[] for i in node_conductance}
for i in file_precision:
    arr = i.split()
    for i in range(len(arr)):
        arr[i] = int(arr[i])
    for j in presence:
        if j in arr:
            presence[j].append(arr)

# %%
present = []
for i in node_conductance:
    for j in range(len(node_conductance[i])):
        for k in range(len(presence[i])):
            if node_conductance[i][j] in presence[i][k]:
                present.append((i,k,j))

# %%
present
# Out:
# [(514553, 5, 0),
#  (514553, 7, 0),
#  (514553, 9, 0),
#  (514553, 11, 0),
#  (514553, 0, 1),
#  (514553, 1, 1),
#  (514553, 2, 1),
#  (514553, 3, 1),
#  (514553, 4, 1),
#  (514553, 5, 1),
#  (514553, 7, 1),
#  (514553, 8, 1),
#  (514553, 9, 1),
#  (514553, 10, 1),
#  (514553, 11, 1),
#  (514553, 12, 1),
#  (514553, 5, 2),
#  (514553, 6, 2),
#  (514553, 7, 2),
#  (514553, 8, 2),
#  (514553, 9, 2),
#  (514553, 10, 2),
#  (514553, 12, 2),
#  (514553, 5, 3),
#  (514553, 7, 3),
#  (514553, 8, 3),
#  (514553, 9, 3),
#  (514553, 10, 3),
#  (514553, 11, 3),
#  (514553, 12, 3),
#  (514553, 0, 4),
#  (514553, 1, 4),
#  (514553, 2, 4),
#  (514553, 3, 4),
#  (514553, 4, 4),
#  (514553, 5, 4),
#  (514553, 6, 4),
#  (514553, 7, 4),
#  (514553, 8, 4),
#  (514553, 9, 4),
#  (514553, 10, 4),
#  (514553, 11, 4),
#  (514553, 12, 4),
#  (514553, 13, 4),
#  (514553, 5, 5),
#  (514553, 7, 5),
#  (514553, 8, 5),
#  (143608, 3, 9),
#  (143608, 4, 9),
#  (143608, 5, 9),
#  (143608, 6, 9),
#  (143608, 7, 9),
#  (143608, 8, 9),
#  (143608, 1, 10),
#  (143608, 2, 10),
#  (143608, 3, 10),
#  (143608, 4, 10),
#  (143608, 5, 10),
#  (143608, 6, 10),
#  (143608, 7, 10),
#  (143608, 8, 10),
#  (143608, 3, 11),
#  (143608, 4, 11),
#  (143608, 5, 11),
#  (143608, 6, 11),
#  (143608, 7, 11),
#  (143608, 8, 11),
#  (143608, 2, 12),
#  (143608, 3, 12),
#  (143608, 4, 12),
#  (143608, 5, 12),
#  (143608, 6, 12),
#  (143608, 7, 12),
#  (143608, 8, 12),
#  (243284, 0, 0),
#  (243284, 1, 0),
#  (243284, 0, 1),
#  (243284, 0, 2),
#  (243284, 1, 2),
#  (243284, 0, 3),
#  (243284, 1, 3),
#  (243284, 0, 4),
#  (243284, 1, 4),
#  (243284, 0, 5),
#  (243284, 0, 6),
#  (243284, 0, 7),
#  (243284, 0, 8),
#  (243284, 1, 8),
#  (243284, 0, 9),
#  (243284, 1, 9),
#  (243284, 0, 10),
#  (152623, 1, 0),
#  (152623, 3, 0),
#  (152623, 0, 1),
#  (152623, 1, 1),
#  (152623, 2, 1),
#  (152623, 3, 1),
#  (152623, 4, 1),
#  (152623, 1, 2),
#  (152623, 3, 2),
#  (152623, 1, 3),
#  (152623, 2, 3),
#  (152623, 3, 3),
#  (152623, 1, 4),
#  (152623, 2, 4),
#  (152623, 3, 4),
#  (152623, 1, 5),
#  (152623, 2, 5),
#  (152623, 3, 5),
#  (152623, 0, 6),
#  (152623, 1, 6),
#  (152623, 2, 6),
#  (152623, 3, 6),
#  (152623, 1, 7),
#  (152623, 3, 7),
#  (152623, 4, 7),
#  (152623, 1, 9),
#  (152623, 2, 9),
#  (152623, 3, 9),
#  (152623, 1, 10),
#  (152623, 2, 10),
#  (152623, 3, 10),
#  (152623, 0, 11),
#  (152623, 1, 11),
#  (152623, 2, 11),
#  (152623, 3, 11),
#  (152623, 0, 12),
#  (152623, 1, 12),
#  (152623, 2, 12),
#  (152623, 3, 12),
#  (152623, 1, 13),
#  (152623, 3, 13),
#  (152623, 1, 14),
#  (152623, 3, 14),
#  (152623, 4, 14),
#  (152623, 1, 15),
#  (152623, 2, 15),
#  (152623, 3, 15)]

# %%
num_comm = {i:[] for i in node_conductance}
for i in node_conductance:
    for j in present:
        if i==j[0]:
            if j[1] not in num_comm[i]:
                num_comm[i].append(j[1])

# %%
new_num_comm = {i:{j:[] for j in num_comm[i]} for i in num_comm}

# %%
for i in new_num_comm:
    for j in new_num_comm[i]:
        for k in present:
            if i==k[0] and k[1]==j:
                new_num_comm[i][j].append(node_conductance[i][k[2]])

# %%
for i in new_num_comm:
    for j in new_num_comm[i]:
        plt.figure()
        plt.title('Precision for seed node '+str(i))
        plt.xlabel('k')
        plt.ylabel('Fraction of points in community '+str(j))
        frac = [i1/len(node_conductance[i]) for i1 in range(1,len(new_num_comm[i][j])+1)]
        plt.plot(range(len(new_num_comm[i][j])),frac)
